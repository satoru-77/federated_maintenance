# %%
import os

files = [
    'best_model_FD001.pt', 'best_model_FD002.pt', 
    'best_model_FD003.pt', 'best_model_FD004.pt',
    'scaler_FD001.pkl', 'scaler_FD002.pkl',
    'scaler_FD003.pkl', 'scaler_FD004.pkl',
    'useful_sensors_FD001.pkl', 'useful_sensors_FD002.pkl',
    'useful_sensors_FD003.pkl', 'useful_sensors_FD004.pkl',
]

for f in files:
    status = "EXISTS" if os.path.exists(f) else "MISSING"
    print(f"{status}  {f}")
# Out:
# EXISTS  best_model_FD001.pt
# EXISTS  best_model_FD002.pt
# EXISTS  best_model_FD003.pt
# EXISTS  best_model_FD004.pt
# EXISTS  scaler_FD001.pkl
# EXISTS  scaler_FD002.pkl
# EXISTS  scaler_FD003.pkl
# EXISTS  scaler_FD004.pkl
# EXISTS  useful_sensors_FD001.pkl
# EXISTS  useful_sensors_FD002.pkl
# EXISTS  useful_sensors_FD003.pkl
# EXISTS  useful_sensors_FD004.pkl
